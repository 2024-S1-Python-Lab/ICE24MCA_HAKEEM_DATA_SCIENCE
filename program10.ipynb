# %%
import numpy as np
import pandas as pd

# %%
data = {'Name':['Tom', 'nick', 'krish', 'jack'],'Age':[20, 21, 19, 18]}
df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age
# 0    Tom   20
# 1   nick   21
# 2  krish   19
# 3   jack   18

# %%
data = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
'Age':[27, 24, 22, 32],
'Address':['Delhi', 'Kanpur', 'Allahabad', 'Kannauj'],
'Qualification':['Msc', 'MA', 'MCA', 'Phd']}
df = pd.DataFrame(data)
print(df[['Name', 'Qualification']])
# Out:
#      Name Qualification
# 0     Jai           Msc
# 1  Princi            MA
# 2  Gaurav           MCA
# 3    Anuj           Phd

# %%
data =pd.read_csv("/content/empl.csv")
print(data)
# Out:
#     EMPLOYEE_ID      NAME     EMAIL  PHONE_NUMBER  HIRE_DATE DESIGNATION  \
# 0         198.0    Donald  DOCONNEL  650.507.9833  21-Jun-07    SH_CLERK
# 1         199.0   Douglas    DGRANT  650.507.9844  13-Jan-08    SH_CLERK
# 2         200.0  Jennifer   JWHALEN  515.123.4444  17-Sep-03    SH_CLERK
# 3         201.0   Michael  MHARTSTE  515.123.5555  17-Feb-04    SH_CLERK
# 4         105.0     David   DAUSTIN  590.423.4569  25-Jun-05     IT_PROG
# 5         106.0    Shanta  SVOLLMAN  650.123.4234  10-Oct-05     IT_PROG
# 6         107.0     Kevin  KMOURGOS  650.123.5234  16-Nov-07     IT_PROG
# 7         108.0     Julia    JNAYER  650.124.1214  16-Jul-05    ST_CLERK
# 8         109.0     Irene  IMIKKILI  650.124.1224  28-Sep-06    ST_CLERK
# 9         110.0     James   JLANDRY  650.124.1334  14-Jan-07    ST_CLERK
# 10        111.0    Steven   SMARKLE  650.124.1434  08-Mar-08    ST_CLERK
# 11        112.0     Laura   LBISSOT  650.124.5234  20-Aug-05    ST_CLERK
# 12          NaN       NaN       NaN           NaN        NaN         NaN
# 13          NaN       NaN       NaN           NaN        NaN         NaN
# 14          NaN       NaN       NaN           NaN        NaN         NaN
# 15          NaN       NaN       NaN           NaN        NaN         NaN
# 16          NaN       NaN       NaN           NaN        NaN         NaN
# 17          NaN       NaN       NaN           NaN        NaN         NaN
# 18          NaN       NaN       NaN           NaN        NaN         NaN
# 19          NaN       NaN       NaN           NaN        NaN         NaN
# 20          NaN       NaN       NaN           NaN        NaN         NaN
# 21          NaN       NaN       NaN           NaN        NaN         NaN
# 22          NaN       NaN       NaN           NaN        NaN         NaN
#
#      SALARY  MANAGER_ID  DEPARTMENT_ID
# 0   12600.0       124.0           50.0
# 1   12600.0       124.0           50.0
# 2   14400.0       101.0           10.0
# 3   13000.0       100.0           20.0
# 4    4800.0       103.0           60.0
# 5    6500.0       100.0           50.0
# 6    5800.0       100.0           50.0
# 7    3200.0       120.0           50.0
# 8    2700.0       120.0           50.0
# 9    2400.0       120.0           50.0
# 10   2200.0       120.0           50.0
# 11   3300.0       121.0           50.0
# 12      NaN         NaN            NaN
# 13      NaN         NaN            NaN
# 14      NaN         NaN            NaN
# 15      NaN         NaN            NaN
# 16      NaN         NaN            NaN
# 17      NaN         NaN            NaN
# 18      NaN         NaN            NaN
# 19      NaN         NaN            NaN
# 20      NaN         NaN            NaN
# 21      NaN         NaN            NaN
# 22      NaN         NaN            NaN

# %%
data.info(0)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   EMPLOYEE_ID    12 non-null     float64
#  1   NAME           12 non-null     object
#  2   EMAIL          12 non-null     object
#  3   PHONE_NUMBER   12 non-null     object
#  4   HIRE_DATE      12 non-null     object
#  5   DESIGNATION    12 non-null     object
#  6   SALARY         12 non-null     float64
#  7   MANAGER_ID     12 non-null     float64
#  8   DEPARTMENT_ID  12 non-null     float64
# dtypes: float64(4), object(5)
# memory usage: 1.7+ KB

# %%
data.head()
# Out:
#    EMPLOYEE_ID      NAME     EMAIL  PHONE_NUMBER  HIRE_DATE DESIGNATION  \
# 0        198.0    Donald  DOCONNEL  650.507.9833  21-Jun-07    SH_CLERK
# 1        199.0   Douglas    DGRANT  650.507.9844  13-Jan-08    SH_CLERK
# 2        200.0  Jennifer   JWHALEN  515.123.4444  17-Sep-03    SH_CLERK
# 3        201.0   Michael  MHARTSTE  515.123.5555  17-Feb-04    SH_CLERK
# 4        105.0     David   DAUSTIN  590.423.4569  25-Jun-05     IT_PROG
#
#     SALARY  MANAGER_ID  DEPARTMENT_ID
# 0  12600.0       124.0           50.0
# 1  12600.0       124.0           50.0
# 2  14400.0       101.0           10.0
# 3  13000.0       100.0           20.0
# 4   4800.0       103.0           60.0

# %%
first=data.head()
print (first)
# Out:
#    EMPLOYEE_ID      NAME     EMAIL  PHONE_NUMBER  HIRE_DATE DESIGNATION  \
# 0        198.0    Donald  DOCONNEL  650.507.9833  21-Jun-07    SH_CLERK
# 1        199.0   Douglas    DGRANT  650.507.9844  13-Jan-08    SH_CLERK
# 2        200.0  Jennifer   JWHALEN  515.123.4444  17-Sep-03    SH_CLERK
# 3        201.0   Michael  MHARTSTE  515.123.5555  17-Feb-04    SH_CLERK
# 4        105.0     David   DAUSTIN  590.423.4569  25-Jun-05     IT_PROG
#
#     SALARY  MANAGER_ID  DEPARTMENT_ID
# 0  12600.0       124.0           50.0
# 1  12600.0       124.0           50.0
# 2  14400.0       101.0           10.0
# 3  13000.0       100.0           20.0
# 4   4800.0       103.0           60.0

# %%
import pandas as pd
import numpy as np
arr=np.array([10,15,18,22])
s = pd.Series(arr)
print(s)
# Out:
# 0    10
# 1    15
# 2    18
# 3    22
# dtype: int64

# %%
arr=np.array(['a','b','c','d'])
s=pd.Series(arr, index=['first','second','third','fourth'])
print(s)
# Out:
# first     a
# second    b
# third     c
# fourth    d
# dtype: object

# %%
s=pd.Series(50, index=[0, 1, 2, 3, 4])
print (s)
# Out:
# 0    50
# 1    50
# 2    50
# 3    50
# 4    50
# dtype: int64

# %%
d={'Name': 'Deepthi', 'Class' : 'MCA', 'year' : 2014}
s=pd.Series(d)
print(s)
# Out:
# Name     Deepthi
# Class        MCA
# year        2014
# dtype: object

# %%
s = pd.Series([10,15,18,22])
df=pd.DataFrame(s)
df.columns=['List1']
df['List2']=20
df['List3']=df['List1']+df['List2']
print(df)
# Out:
#    List1  List2  List3
# 0     10     20     30
# 1     15     20     35
# 2     18     20     38
# 3     22     20     42

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(0)
values = np.random.randn(100)
s = pd.Series(values)
print("series\n",s)
s.plot(kind='hist', title='Normally distributed random values')
plt.show()
# Out:
# series
#  0     1.764052
# 1     0.400157
# 2     0.978738
# 3     2.240893
# 4     1.867558
#         ...
# 95    0.706573
# 96    0.010500
# 97    1.785870
# 98    0.126912
# 99    0.401989
# Length: 100, dtype: float64

# %%
s.describe()
# Out:
# count    100.000000
# mean       0.059808
# std        1.012960
# min       -2.552990
# 25%       -0.643857
# 50%        0.094096
# 75%        0.737077
# max        2.269755
# dtype: float64

# %%
df = pd.DataFrame({'A': [1, 2, 1, 4, 3],
'B': [12, 14, 11, 16, 18],
'C': ['a', 'a', 'b', 'a', 'b']})
df
# Out:
#    A   B  C
# 0  1  12  a
# 1  2  14  a
# 2  1  11  b
# 3  4  16  a
# 4  3  18  b

# %%
df.describe()
# Out:
#              A          B
# count  5.00000   5.000000
# mean   2.20000  14.200000
# std    1.30384   2.863564
# min    1.00000  11.000000
# 25%    1.00000  12.000000
# 50%    2.00000  14.000000
# 75%    3.00000  16.000000
# max    4.00000  18.000000

# %%
import pandas
iris=pandas.read_csv('/content/Iris_new.csv')
print(iris)
# Out:
#     Id  SepalLength  SepalWidth  PetalLength  PetalWidth          Species
# 0    1          5.1         3.5          1.4         0.2      Iris-setosa
# 1    2          4.9         3.0          1.4         0.2      Iris-setosa
# 2    3          4.7         3.2          1.3         0.2      Iris-setosa
# 3    4          4.6         3.1          1.5         0.2      Iris-setosa
# 4    5          5.0         3.6          1.4         0.2      Iris-setosa
# 5    6          5.4         3.9          1.7         0.4      Iris-setosa
# 6    7          4.6         3.4          1.4         0.3      Iris-setosa
# 7    8          5.0         3.4          1.5         0.2      Iris-setosa
# 8    9          4.4         2.9          1.4         0.2      Iris-setosa
# 9   10          4.9         3.1          1.5         0.1      Iris-setosa
# 10  11          7.0         3.2          4.7         1.4  Iris-versicolor
# 11  12          6.4         3.2          4.5         1.5  Iris-versicolor
# 12  13          6.9         3.1          4.9         1.5  Iris-versicolor
# 13  14          5.5         2.3          4.0         1.3  Iris-versicolor
# 14  15          6.5         2.8          4.6         1.5  Iris-versicolor
# 15  16          5.7         2.8          4.5         1.3  Iris-versicolor
# 16  17          6.3         3.3          4.7         1.6  Iris-versicolor
# 17  18          4.9         2.4          3.3         1.0  Iris-versicolor
# 18  19          6.6         2.9          4.6         1.3  Iris-versicolor
# 19  20          5.2         2.7          3.9         1.4  Iris-versicolor
# 20  21          6.3         3.3          6.0         2.5   Iris-virginica
# 21  22          5.8         2.7          5.1         1.9   Iris-virginica
# 22  23          7.1         3.0          5.9         2.1   Iris-virginica
# 23  24          6.3         2.9          5.6         1.8   Iris-virginica
# 24  25          6.5         3.0          5.8         2.2   Iris-virginica
# 25  26          7.6         3.0          6.6         2.1   Iris-virginica
# 26  27          4.9         2.5          4.5         1.7   Iris-virginica
# 27  28          7.3         2.9          6.3         1.8   Iris-virginica
# 28  29          6.7         2.5          5.8         1.8   Iris-virginica
# 29  30          7.2         3.6          6.1         2.5   Iris-virginica

# %%
import pandas as pd
iris=pandas.read_csv('/content/Iris_new.csv')
print(iris.head())
# Out:
#    Id  SepalLength  SepalWidth  PetalLength  PetalWidth      Species
# 0   1          5.1         3.5          1.4         0.2  Iris-setosa
# 1   2          4.9         3.0          1.4         0.2  Iris-setosa
# 2   3          4.7         3.2          1.3         0.2  Iris-setosa
# 3   4          4.6         3.1          1.5         0.2  Iris-setosa
# 4   5          5.0         3.6          1.4         0.2  Iris-setosa

# %%
import pandas as pd
df = pd.DataFrame(pd.read_csv("/content/Iris_new.csv"))
df.hist()
# Out:
# array([[<Axes: title={'center': 'Id'}>,
#         <Axes: title={'center': 'SepalLength'}>],
#        [<Axes: title={'center': 'SepalWidth'}>,
#         <Axes: title={'center': 'PetalLength'}>],
#        [<Axes: title={'center': 'PetalWidth'}>, <Axes: >]], dtype=object)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data=pd.read_csv('/content/Iris_new.csv')
data.info()
data.describe()
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Id           30 non-null     int64
#  1   SepalLength  30 non-null     float64
#  2   SepalWidth   30 non-null     float64
#  3   PetalLength  30 non-null     float64
#  4   PetalWidth   30 non-null     float64
#  5   Species      30 non-null     object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 1.5+ KB
#    Id  SepalLength  SepalWidth  PetalLength  PetalWidth      Species
# 0   1          5.1         3.5          1.4         0.2  Iris-setosa
# 1   2          4.9         3.0          1.4         0.2  Iris-setosa
# 2   3          4.7         3.2          1.3         0.2  Iris-setosa
# 3   4          4.6         3.1          1.5         0.2  Iris-setosa
# 4   5          5.0         3.6          1.4         0.2  Iris-setosa

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=sns.load_dataset('tips')
sns.scatterplot(x='total_bill',y='tip',data=data)
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv('/content/sample_data/california_housing_test.csv')
plt.figure(figsize=(10,8))
sns.scatterplot(x='longitude',y='latitude',data=data)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()
